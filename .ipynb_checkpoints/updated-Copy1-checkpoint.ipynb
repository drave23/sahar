# %% [markdown]
# <h1> assigment 3 </h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output, Image, display

# %% [markdown]
# **Define dataset folder and files**

# %% [markdown]
# חלק א - ניתוח מידע

# %%
# lets explore movies.csv
d_columns = ['user_id','item_id','rating','timestamp']
b = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.base',delimiter='\t',names=d_columns)
d12 = b.drop(['user_id', 'timestamp'], axis = 1)
m_cols = ['movie_id','movie title','release date','video release date','IMDb URL'
          ,'unknown','Action','Adventure','Animation','Childrens','Comedy',
          'Crime','Documentary','Drama','Fantasy','Film-Noir','Horror','Musical','Mystery','Romance','Sci-Fi',
        'Thriller','War','Western']
data= pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.item',delimiter='|',names=m_cols,encoding='latin-1')
data.shape
# Out:
# (1682, 24)

# %%
#explore users
u_cols = ['user_id','age','gender','occupation','zip_code']
data_u = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.user',delimiter='|',names=u_cols,encoding='latin-1')
data_u.shape
# Out:
# (943, 5)

# %%
r_cols = ['user_id','movie_id','rating','timestamp']
data_r = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.base',delimiter='\t',names=r_cols,encoding='latin-1')
data_r.shape
#print(data_r)
# Out:
# (80000, 4)

# %%
# 1.1
dataRating=data.merge(data_r,on = 'movie_id',how = 'inner')
averageMovieRating = dataRating.groupby(['movie_id', 'movie title'])['rating'].mean().sort_values(ascending=False).reset_index()

print('average rating to number of movies')
plt.hist(averageMovieRating['rating'],bins='auto')
plt.xlabel('Average Rating')
plt.ylabel('# of Movies')
#plt.c='g'
plt.show()

bestRating = averageMovieRating.head(3)
print(bestRating)
# Out:
# average rating to number of movies
#    movie_id                                 movie title  rating
# 0      1500                   Santa with Muscles (1996)     5.0
# 1      1201  Marlene Dietrich: Shadow and Light (1996)      5.0
# 2      1293                             Star Kid (1997)     5.0

# %%
#1.2

merged_data=dataRating.merge(data_u,on = 'user_id', how='inner')

femaleData = merged_data.loc[merged_data['gender'] == 'F']
maleData = merged_data.loc[merged_data['gender'] == 'M']

# %%
#female
averageMovieRatingFemale = femaleData.groupby(['movie_id','movie title','gender'])['rating'].mean().sort_values(ascending=False).reset_index()

averageMovieRatingFemale.columns = ['movie_id','movie title','gender', 'ratingFemale']
print('average rating to number of movies - female')
plt.hist(averageMovieRatingFemale['ratingFemale'],bins='auto')
plt.xlabel('Average Rating')
plt.ylabel('# of Movies')
plt.show()
bestRating = averageMovieRatingFemale.head(3)
print(bestRating)
# Out:
# average rating to number of movies - female
#    movie_id                            movie title gender  ratingFemale
# 0      1472  Visitors, The (Visiteurs, Les) (1993)      F           5.0
# 1      1594                         Everest (1998)      F           5.0
# 2      1599          Someone Else's America (1995)      F           5.0

# %%
#male

averageMovieRatingMale = maleData.groupby(['movie_id','movie title','gender'])['rating'].mean().sort_values(ascending=False).reset_index()
averageMovieRatingMale.columns = ['movie_id','movie title','gender', 'ratingMale']
print('average rating to number of movies - male')
plt.hist(averageMovieRatingMale['ratingMale'],bins='auto')
plt.xlabel('Average Rating')
plt.ylabel('# of Movies')
plt.show()
bestRating = averageMovieRatingMale.head(3)
print(bestRating)
# Out:
# average rating to number of movies - male
#    movie_id                     movie title gender  ratingMale
# 0      1293                 Star Kid (1997)      M         5.0
# 1      1656              Little City (1998)      M         5.0
# 2      1122  They Made Me a Criminal (1939)      M         5.0

# %%
males_and_females_ratings = averageMovieRatingMale.merge(averageMovieRatingFemale,on="movie_id")
#print(males_and_females_ratings)
#print(males_and_females_ratings[['movie title_x','ratingMale','ratingFemale']])

difference_between_genders=males_and_females_ratings.apply(lambda row: (abs(row['ratingMale']-row['ratingFemale'])), axis=1)
difference_between_genders_df = pd.DataFrame({'movieid':difference_between_genders.index, 'difference':difference_between_genders.values})
#difference_between_genders["movieID"] = males_and_females_ratings["movie_id"].values
x = np.array(males_and_females_ratings["movie_id"].values)
y = np.array(difference_between_genders)
z = np.array(males_and_females_ratings["movie title_x"].values)
df = pd.DataFrame({'movieID':x,'movieTitle':z, 'res':y})
df.sort_values('res', inplace=True, ascending=False)
print('סרטים עם הפער הגבוה ביותר בין נשים וגברים')
print(df.head(5))

print('סרטים עם הפער הנמוך ביותר בין נשים וגברים')
print(df.tail(5))


print(df['res'].mean())
# Out:
# סרטים עם הפער הגבוה ביותר בין נשים וגברים
#     movieID                                   movieTitle       res
# 1      1175                             Hugo Pool (1997)  4.000000
# 7       851  Two or Three Things I Know About Her (1966)  3.666667
# 15     1429                         Sliding Doors (1998)  3.500000
# 16      641                        Paths of Glory (1957)  3.461538
# 50     1592                       Magic Hour, The (1998)  3.250000
# סרטים עם הפער הנמוך ביותר בין נשים וגברים
#       movieID                   movieTitle  res
# 164      1194    Once Were Warriors (1994)  0.0
# 1324     1289        Jack and Sarah (1995)  0.0
# 939       914           Wild Things (1998)  0.0
# 909        34  Doom Generation, The (1995)  0.0
# 945      1454  Angel and the Badman (1947)  0.0
# 0.5309060513841749

# %%
1.2
ניתן לראות כי דירוגי הגברים הם מעט גבוהים יותר מאשר הנשים אך אין מסקנה איכותית שניתן להסיק מתוצאות אלה
שאר התוצאות הרצויות סרטים בעלי הדירוג הגבוה ביתור ולנשים\גברים ובעלי הפער הגדול ביותר מוצגים בטבלאות
# Out:
#   File "<ipython-input-166-dbf06ae8b06e>", line 2
#     ניתן לראות כי דירוגי הגברים הם מעט גבוהים יותר מאשר הנשים אך אין מסקנה איכותית שניתן להסיק מתוצאות אלה
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# #1.3

# %%
m_cols = ['unknown','Action','Adventure','Animation','Childrens','Comedy',
          'Crime','Documentary','Drama','Fantasy','Film-Noir','Horror','Musical','Mystery','Romance','Sci-Fi',
        'Thriller','War','Western']
def showPraph(m_cols,high_rated,title):
    
    genres_count = {}
    for g in m_cols:
        count = 0
        genre_movies = high_rated[g] == 1
        genres_count[g] = high_rated[genre_movies].shape[0]
    genres_count_list = sorted(genres_count.items(), key=operator.itemgetter(1),reverse=True)
    #print(genres_count_list)
    # lets display the same result in the histogram
    fig = plt.figure(1, figsize=(18,13))
    ax2 = fig.add_subplot(2,1,2)
    y_axis = [genres_count[i] for i in genres_count]
    x_axis = [i for i in range(len(genres_count))]
    x_label = [i for i in genres_count]
    plt.xticks(rotation=85, fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.xticks(x_axis, x_label)
    plt.ylabel("No. of occurences", fontsize = 24, labelpad = 0)
    ax2.bar(x_axis, y_axis, align = 'center', color='g')
    plt.title(title,bbox={'facecolor':'k', 'pad':5},color='w',fontsize = 30)
    plt.show()

# %%
import operator
showPraph(m_cols,data,"Popularity of Genres")

# %% [markdown]
# **high rating > 4 male and female **

# %%
movhigh = pd.merge(averageMovieRating,data, left_index=True,right_on='movie_id', how='outer')
high_rated_indexes = movhigh['rating']>4.0
high_rated = movhigh[high_rated_indexes]
showPraph(m_cols,high_rated,"Popularity of Genres - high rating")

# %%
movhigh1 = pd.merge(averageMovieRating,data, left_index=True,right_on='movie_id', how='outer')
low_rated_indexes = movhigh1['rating']<2.5
low_rated = movhigh1[low_rated_indexes]
showPraph(m_cols,low_rated,"Popularity of Genres - low rating")

# %%
female_average_rating_genre=pd.merge(averageMovieRatingFemale,data, left_index=True,right_on='movie_id', how='inner')
#print(female_average_rating_genre)
low_rated_female_indexes1 = female_average_rating_genre['ratingFemale']<2.0
low_rated_female = female_average_rating_genre[low_rated_female_indexes1]
#print(low_rated_indexes1)
showPraph(m_cols,low_rated_female,"female - low rating")

high_rated_indexes1 = female_average_rating_genre['ratingFemale']>4.0
high_rated_female = female_average_rating_genre[high_rated_indexes1]
showPraph(m_cols,high_rated_female,"female - high rating")

# %% [markdown]
# 1.3 תשובות
# עבור מרבית האוכלוסיה בכלל ונשים וגברים בפרט ניתן לראות כי הזאנר המוביל הוא דרמה והכי פחות הוא פנטזיה, באופן כללי על פי הדאטה סט הנתון לא ניתן לראות הבדלים מובהקים בין חתך הנשים לחתך הגברים , הגרפים המייצגים את אוכלוסיות אלה דומים מאוד.

# %%
male_average_rating_genre=pd.merge(averageMovieRatingMale,data, left_index=True,right_on='movie_id', how='inner')
#print(female_average_rating_genre)
low_rated_male_indexes1 = male_average_rating_genre['ratingMale']<2.0
low_rated_male = male_average_rating_genre[low_rated_male_indexes1]
#print(low_rated_indexes1)
showPraph(m_cols,low_rated_male,"male - low rating")

high_rated_indexes1 = male_average_rating_genre['ratingMale']>4.0
high_rated_male = male_average_rating_genre[high_rated_indexes1]
showPraph(m_cols,high_rated_male,"male - high rating")

# %%
dataamit= pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.item',delimiter='|',names=m_cols,encoding='latin-1')
print("popularity determine by number of raters and average rating")
#print(d12)
x=d12.groupby(['item_id'])
#print(d12)
most_popular_movies = x.agg(lambda x: 0.5* x.mean() + 0.5* x.count()).sort_values('rating', ascending=False)


display(most_popular_movies.head(10))
# Out:
# popularity determine by number of raters and average rating
#              rating
# item_id
# 50       244.179752
# 181      213.005924
# 258      202.911692
# 100      199.554430
# 294      198.582487
# 288      197.222506
# 286      195.820876
# 1        193.446475
# 121      178.195467
# 300      177.828125

# %% [markdown]
# q2.1

# %%
import numpy

# %%
def PredictionMovieAvg(movie_id):
    r = averageMovieRating[averageMovieRating['movie_id']==movie_id]
    if r.empty:
        return numpy.mean(averageMovieRating['rating'])
    else:
        return r.iloc[0]['rating']

# %%
tcols = ['user_id','movie_id','rating','timestamp']
data_test = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.test',delimiter='\t',names=tcols,encoding='latin-1')
#data_test.shape
#merging two dataframes movies and ratings
t_set=data.merge(data_test,on = 'movie_id',how = 'inner')
for index, row in t_set.iterrows():  
    t_set.set_value(index,'pridected_rating_by_movie_avg',PredictionMovieAvg(row['movie_id']))

# %%
t_set['dif_movie_avg_pridct_with_actual']=(t_set['rating']-t_set['pridected_rating_by_movie_avg']).abs()
mae_pridct_by_movie_avg=numpy.mean(t_set['dif_movie_avg_pridct_with_actual'])
print("MAE:",mae_pridct_by_movie_avg)
# Out:
# MAE: 0.8272262612291202

# %% [markdown]
# q2.2

# %%
m_cols = ['movie_id','movie title','release date','video release date','IMDb URL'
          ,'unknown','Action','Adventure','Animation','Childrens','Comedy',
          'Crime','Documentary','Drama','Fantasy','Film-Noir','Horror','Musical','Mystery','Romance','Sci-Fi',
        'Thriller','War','Western']

# %%
dataamit= pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.item',delimiter='|',names=m_cols,encoding='latin-1')
from IPython.display import display
colMoviesRecom = ['user_id','movie_id']
data_columns = ['user_id','movie_id','rating','timestamp']

base = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.base',delimiter='\t',names=data_columns)
data1 = base.drop(['user_id', 'timestamp'], axis = 1)

#print(base)
data_by_item_id = data1.groupby(['movie_id'])
#print(data_by_item_id.count())

mean_rating_per_item_id = data_by_item_id.mean().reset_index('movie_id').sort_values('rating', ascending=False)

#print(mean_rating_per_item_id)

moviesRecommandAve = pd.DataFrame(columns = colMoviesRecom)
#print(moviesRecommandAve)
train_user_id_movie_id = base.drop(['rating', 'timestamp'], axis = 1)
Testusers = (data_test['user_id']).unique()
#print(Testusers)
for user_id in Testusers:
    rows_with_user_id = train_user_id_movie_id[train_user_id_movie_id['user_id'] == user_id]
    movies_wasnt_watched = mean_rating_per_item_id[~mean_rating_per_item_id.movie_id.isin(rows_with_user_id.movie_id)]
    moviesNotWatch = movies_wasnt_watched.head(20).drop(['rating'],axis=1)
    moviesRecommandAve = moviesRecommandAve.append(moviesNotWatch.assign(user_id = user_id))
print('top 20 movies with the best average rating')
#print(dataamit)
dataRating=dataamit.merge(moviesRecommandAve,on = 'movie_id',how = 'inner')
#display(dataRating)
#print(dataRating.groupby(['user_id']).count())
amit=dataRating[['user_id','movie title']]
display(amit.sort_values('user_id',  ascending=True))
#print(moviesRecommandAve)
# Out:
# top 20 movies with the best average rating
#       user_id                                        movie title
# 0         1.0                         Usual Suspects, The (1995)
# 7770      1.0                      Someone Else's America (1995)
# 7312      1.0                                     Everest (1998)
# 6853      1.0                          Santa with Muscles (1996)
# 6395      1.0               Saint of Fort Washington, The (1993)
# 5939      1.0                             Pather Panchali (1955)
# 5481      1.0                                       Faust (1994)
# 5023      1.0                                    Star Kid (1997)
# 8262      1.0                           Some Mother's Son (1996)
# 4565      1.0         Marlene Dietrich: Shadow and Light (1996)
# 3518      1.0                     They Made Me a Criminal (1939)
# 3060      1.0                        Perfect Candidate, A (1996)
# 2839      1.0                                 Rear Window (1954)
# ...

# %%
recoMoviesRandom = pd.DataFrame(columns = colMoviesRecom)
for user_id in test_unique_users:
    rows_with_user_id = train_user_id_movie_id[train_user_id_movie_id['user_id'] == user_id]
    movies_wasnt_watched = mean_rating_per_item_id[~mean_rating_per_item_id.movie_id.isin(rows_with_user_id.movie_id)]
    moviesNotWatch = movies_wasnt_watched.sample(20).drop(['rating'],axis=1)
    recoMoviesRandom = recoMoviesRandom.append(moviesNotWatch.assign(user_id = user_id))
print('20 movies to recommand - random:')
diei=dataamit.merge(recoMoviesRandom,on = 'movie_id',how = 'inner')
amit=diei[['user_id','movie title']]
display(amit.sort_values('user_id',  ascending=True))
# Out:
# 20 movies to recommand - random:
#       user_id                                        movie title
# 3506      1.0                                Paris, Texas (1984)
# 8405      1.0                  Beans of Egypt, Maine, The (1994)
# 5395      1.0                             Stealing Beauty (1996)
# 4125      1.0                            Don Juan DeMarco (1995)
# 9054      1.0                    Getting Away With Murder (1996)
# 5346      1.0                                   Cabin Boy (1994)
# 4382      1.0                           Mrs. Winterbourne (1996)
# 8443      1.0                                   Dream Man (1995)
# 3870      1.0                             Made in America (1993)
# 5819      1.0                            Albino Alligator (1996)
# 8762      1.0                    Reluctant Debutante, The (1958)
# 6229      1.0                             In Love and War (1996)
# 534       1.0                     All Dogs Go to Heaven 2 (1996)
# ...

# %%
def get_movies_user_saw(user_id,data_test):
    return data_test[data_test["user_id"]==user_id]

# %%
def get_movies_user_reccoment_new(user_id,df):
    return df[df["user_id"]==user_id]

# %%
def calc_recall_and_precision(df,data_test):
    users_from_t_set=data_test.user_id.unique()
    results=pd.DataFrame(users_from_t_set,columns=['user_id'])
    for index, row in results.iterrows():
        s=get_movies_user_reccoment_new(row['user_id'],df)
        movies_user_actual_saw=get_movies_user_saw(row['user_id'],data_test)
        intersection = pd.merge(s, movies_user_actual_saw, how='inner', on=['movie_id'])
        #print(intersection)
        recall=len(intersection.index)/len(movies_user_actual_saw.index)
        results.set_value(index,'recall',recall)
        precision=len(intersection.index)/20;
        results.set_value(index,'precision',precision)
    return results

# %%
res_a = calc_recall_and_precision(moviesRecommandAve,data_test)
mean_recall=numpy.mean(res_a['recall'])
print("recall - average:", mean_recall)
mean_precision=numpy.mean(res_a['precision'])
print("precision - average:", mean_precision)
# Out:
# recall: 0.022335341073397418
# precision: 0.045860566448801855

# %%
res = calc_recall_and_precision(recoMoviesRandom,data_test)
mean_recall1=numpy.mean(res['recall'])
print("recall - random:", mean_recall1)
mean_precision1=numpy.mean(res['precision'])
print("precision - random:", mean_precision1)
# Out:
# recall random: 0.014109316875439943
# precision random: 0.03191721132897608

# %% [markdown]
# ניתן לראות כי קיבלנו תוצאות טובות יותר עבור שיטת הממוצע מאשר השיטה הרנדומלית, כפי ציפינו לקבל.
# השיטה הרנדומלית לא לוקחת בחשבון פרמטרים כמו דירוגים קודמים.

# %%
usersTest = data_test.merge(data_u,on='user_id')
female_data = usersTest[usersTest['gender'] == 'F']

female_data = female_data.drop([ 'rating', 'timestamp','age','gender','occupation','zip_code'], axis = 1)

# %%
recMoviesfemale = pd.DataFrame(columns = colMoviesRecom)
femaleTestUsers = (femaleData['user_id']).unique()
for user_id in femaleTestUsers:
    rows_with_user_id = train_user_id_movie_id[train_user_id_movie_id['user_id'] == user_id]
    movies_wasnt_watched = mean_rating_per_item_id[~mean_rating_per_item_id.movie_id.isin(rows_with_user_id.movie_id)]
    moviesNotWatch = movies_wasnt_watched.sample(20).drop(['rating'],axis=1)
    recMoviesfemale = recMoviesfemale.append(moviesNotWatch.assign(user_id = user_id))
print(' 20 movies to recommand-female:')
diei=dataamit.merge(recMoviesfemale,on = 'movie_id',how = 'inner')
amit=diei[['user_id','movie title']]
display(amit.sort_values('user_id',  ascending=True))
#print(recMoviesfemale)
# Out:
#  20 movies to recommand-female:
#       user_id                                        movie title
# 5331      2.0                            Niagara, Niagara (1997)
# 3790      2.0                                Inkwell, The (1994)
# 3322      2.0                              Associate, The (1996)
# 4779      2.0                                    Raw Deal (1948)
# 4678      2.0                              That Darn Cat! (1965)
# 1056      2.0                                    Mad City (1997)
# 1806      2.0  City Slickers II: The Legend of Curly's Gold (...
# 3426      2.0                            Albino Alligator (1996)
# 50        2.0                          Angels and Insects (1995)
# 1513      2.0                                  Casablanca (1942)
# 3687      2.0                                  Relic, The (1997)
# 2801      2.0                             One Night Stand (1997)
# 1204      2.0                            Muriel's Wedding (1994)
# ...

# %%
#print(femaleData.user_id.unique())

res = calc_recall_and_precision(recMoviesfemale,data_test)
#print(res)
mean_recall1=numpy.mean(res['recall'])
print("recall female:", mean_recall1)
mean_precision1=numpy.mean(res['precision'])
print("precision female:", mean_precision1)
# Out:
# recall female: 0.004469558786274623
# precision female: 0.006971677559912851

# %%
usersTest = data_test.merge(data_u,on='user_id')
male_data = usersTest[usersTest['gender'] == 'M']

male_data = male_data.drop([ 'rating', 'timestamp','age','gender','occupation','zip_code'], axis = 1)

# %%
recMoviesmale = pd.DataFrame(columns = colMoviesRecom)
male_test_unique_users = (maleData['user_id']).unique()
for user_id in male_test_unique_users:
    rows_with_user_id = train_user_id_movie_id[train_user_id_movie_id['user_id'] == user_id]
    movies_wasnt_watched = mean_rating_per_item_id[~mean_rating_per_item_id.movie_id.isin(rows_with_user_id.movie_id)]
    top_20_movies_wasnt_watched = movies_wasnt_watched.sample(20).drop(['rating'],axis=1)
    recMoviesmale = recMoviesmale.append(top_20_movies_wasnt_watched.assign(user_id = user_id))
print('20 random movies for each user')
diei=dataamit.merge(recMoviesmale,on = 'movie_id',how = 'inner')
amit=diei[['user_id','movie title']]
display(amit.sort_values('user_id',  ascending=True))
#print(recMoviesmale)
# Out:
# 20 random movies for each user
#        user_id                                        movie title
# 1640       1.0                          Breaking the Waves (1996)
# 978        1.0                                 Kansas City (1996)
# 5874       1.0          Lawnmower Man 2: Beyond Cyberspace (1996)
# 2810       1.0     Mighty Morphin Power Rangers: The Movie (1995)
# 5071       1.0                                   Chinatown (1974)
# 2197       1.0                                    Face/Off (1997)
# 7441       1.0                                    Unzipped (1995)
# 5544       1.0                                  To Die For (1995)
# 3207       1.0                                 Bob Roberts (1992)
# 12484      1.0  Spirits of the Dead (Tre passi nel delirio) (1...
# 10191      1.0                            Before and After (1996)
# 6667       1.0                              Night on Earth (1991)
# 8694       1.0                                   Firestorm (1998)
# ...

# %%
res = calc_recall_and_precision(recMoviesmale,male_data)
#print(res)
mean_recall1=numpy.mean(res['recall'])
print("recall male:", mean_recall1)
mean_precision1=numpy.mean(res['precision'])
print("precision male:", mean_precision1)
# Out:
# recall male: 0.013581681043630348
# precision male: 0.03079268292682929

# %% [markdown]
# בהשוואה לסעיף הקודם קיבלנו תוצאות פחות טובות. בהתייחסות להשוואה בין גברים ונשים התוצאות יצאו פחות או יותר אותו דבר. דבר זה יכול לנבוע מכך שהפעולות הנקיון על הנתונים לא היו מספיק טובות או שלא הנתונים אינם מגוונים מספיק

# %%
#quwstion 4import numpy as np
import pandas as pd
import os
import tensorflow as T
import keras
from keras import backend as K
from keras import initializers
from keras.initializers import RandomNormal
from keras.models import Sequential, Model, load_model, save_model
from keras.layers.core import Dense, Lambda, Activation
from keras.layers import Embedding, Input, Dense, merge, Reshape, Flatten, Dropout
from keras.optimizers import Adagrad, Adam, SGD, RMSprop, Adamax
from keras.regularizers import l2
from keras.layers import Multiply, Concatenate
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from time import time
import multiprocessing as mp
import sys
import math
import argparse
import matplotlib.pyplot as plt

# %%
r_cols = ['userid', 'movieid', 'rating', 'timestamp']
ratingsTrain = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.base', sep='\t', engine='python', encoding='latin-1',names=r_cols)
ratingsTrain['user_emb_id'] = ratingsTrain['userid'] - 1
ratingsTrain['movie_emb_id'] = ratingsTrain['movieid'] - 1

ratingsTest = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u1.test', sep='\t', engine='python', encoding='latin-1',names=r_cols)
ratingsTest['user_emb_id'] = ratingsTest['userid'] - 1
ratingsTest['movie_emb_id'] = ratingsTest['movieid'] - 1

u_cols = ['userid','age','gender','profession', '']
users = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.user', sep='|', engine='python', encoding='latin-1',names=u_cols)
users['gender'] = users['gender'].map({'M': 0, 'F': 1})

i_cols = ['movieid', 'title']
items_df = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.item', sep='|', engine='python', encoding='latin-1', names=i_cols, usecols=[0, 1])

train_df = pd.merge(items_df, ratingsTrain, on='movieid')
test_df = pd.merge(items_df, ratingsTest, on='movieid')
joined_df = pd.concat([train_df, test_df])
Users = joined_df['user_emb_id'].values
Movies = joined_df['movie_emb_id'].values
Ratings = joined_df['rating'].values
max_userid = joined_df['userid'].drop_duplicates().max()
max_movieid = joined_df['movieid'].drop_duplicates().max()

# %%
def get_ncf_model(num_users, num_items, latent_dim, hidden_dim, do, num_of_hidden):
    # Input variables
    user_input = Input(shape=(1,), dtype='int32', name = 'user_input')
    item_input = Input(shape=(1,), dtype='int32', name = 'item_input')

    MF_Embedding_User = Embedding(input_dim = num_users, output_dim = latent_dim, name = 'user_embedding', input_length=1)
    MF_Embedding_Item = Embedding(input_dim = num_items, output_dim = latent_dim, name = 'item_embedding', input_length=1)   
    
    # Crucial to flatten an embedding vector!
    user_latent = Flatten()(MF_Embedding_User(user_input))
    item_latent = Flatten()(MF_Embedding_Item(item_input))
    
    # Element-wise product of user and item embeddings
    conc = Concatenate()([user_latent, item_latent])
    drop = Dropout(0.5)(conc)
    hid1 = Dense(hidden_dim, activation='relu')(drop)
    last_layer = hid1
    for i in range(num_of_hidden - 1):
      hid_amit = Dense(hidden_dim, activation='relu')(last_layer)
      last_layer = hid_amit
    drop2  = Dropout(do)(last_layer)
    prediction = Dense(1, activation='relu', kernel_initializer='lecun_uniform', name = 'prediction')(drop2)
    
    model = Model(inputs=[user_input, item_input], outputs=prediction)

    return model

# %%
K_LATENT = 20
do = 0.5
num_of_nuerons = [15, 20]
num_of_layers = [3]
optimizers = [(Adamax(), 'Adamax'), (SGD(), 'SGD')]
results = []
for layers in num_of_layers:
  for nuerons in num_of_nuerons:
    for opt, opt_name in optimizers:
      NCF_model = get_ncf_model(max_userid, max_movieid, K_LATENT, nuerons, do, layers)
      NCF_model.compile(loss='mse', optimizer=opt, metrics=['mae'])
      callbacks_ncf = [EarlyStopping('val_loss', patience=5)]
      NCF_history = NCF_model.fit([Users, Movies], Ratings, epochs=5, validation_split=.2, verbose=1, callbacks=callbacks_ncf, batch_size = 32)
      results.append((layers, nuerons, opt_name, NCF_history))
# Out:
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/5
# 80000/80000 [==============================] - 5s 60us/step - loss: 2.7276 - mean_absolute_error: 1.3205 - val_loss: 1.1707 - val_mean_absolute_error: 0.8990
# Epoch 2/5
# 80000/80000 [==============================] - 4s 52us/step - loss: 1.2552 - mean_absolute_error: 0.9064 - val_loss: 1.0338 - val_mean_absolute_error: 0.8312
# Epoch 3/5
# 80000/80000 [==============================] - 4s 52us/step - loss: 1.0242 - mean_absolute_error: 0.8156 - val_loss: 0.9872 - val_mean_absolute_error: 0.7997
# Epoch 4/5
# 80000/80000 [==============================] - 4s 53us/step - loss: 0.9974 - mean_absolute_error: 0.8046 - val_loss: 0.9771 - val_mean_absolute_error: 0.7959
# Epoch 5/5
# 80000/80000 [==============================] - 4s 51us/step - loss: 0.9861 - mean_absolute_error: 0.7988 - val_loss: 0.9599 - val_mean_absolute_error: 0.7814
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/5
# ...

# %%
print("Const parameters: Loss Function - MSE")
for num_of_layers, num_of_nuerons, optimizer, history in results:
  avg = np.mean(history.history['mean_absolute_error'])
  epochs = len(history.history['mean_absolute_error'])
  minimum = min(history.history['mean_absolute_error'])
  print("Using", num_of_layers, "hidden layers sized", num_of_nuerons, "," , optimizer, "as optimizer in", epochs, "epochs: Average MAE is", avg,"Min MAE is", minimum)
# Out:
# Const parameters: Loss Function - MSE
# Using 3 hidden layers sized 15 , Adamax as optimizer in 1 epochs: Average MAE is 1.26190865321 Min MAE is 1.26190865321
# Using 3 hidden layers sized 15 , SGD as optimizer in 1 epochs: Average MAE is 0.966823853683 Min MAE is 0.966823853683
# Using 3 hidden layers sized 20 , Adamax as optimizer in 1 epochs: Average MAE is 1.16777355907 Min MAE is 1.16777355907
# Using 3 hidden layers sized 20 , SGD as optimizer in 1 epochs: Average MAE is 0.969352448702 Min MAE is 0.969352448702

# %%
u_cols = ['userid', 'age', 'gender']
users_df = pd.read_csv('d:/documents/users/ravedan/Downloads/ml-100k/u.user', delimiter='|', encoding='latin-1', names=u_cols, usecols=[0, 1, 2])
users_df['gender'].replace('M', 0, inplace=True)
users_df['gender'].replace('F', 1, inplace=True)
joined_with_users_df = pd.merge(joined_df, users_df,on='userid')
Gender = joined_with_users_df['gender'].values
Age = joined_with_users_df['age'].values

# %%
def get_gmf_model_gen(num_users, num_items, latent_dim, do, max_age):
    # Input variables
    user_input = Input(shape=(1,), dtype='int32', name = 'user_input')
    item_input = Input(shape=(1,), dtype='int32', name = 'item_input')
    gender_input = Input(shape=(1,), dtype='float32', name = 'gender_input')
    age_input = Input(shape=(1,), dtype='float32', name = 'age_input')

    MF_Embedding_User = Embedding(input_dim = num_users, output_dim = latent_dim, name = 'user_embedding', input_length=1)
    MF_Embedding_Item = Embedding(input_dim = num_items, output_dim = latent_dim, name = 'item_embedding', input_length=1)
    
    # Crucial to flatten an embedding vector!
    user_latent = Flatten()(MF_Embedding_User(user_input))
    item_latent = Flatten()(MF_Embedding_Item(item_input))
    
    # Element-wise product of user and item embeddings
    hidden1 = Multiply()([user_latent, item_latent])
    conc = Concatenate()([hidden1, gender_input, age_input])
    drop = Dropout(do)(conc)
    prediction = Dense(1, activation='relu', kernel_initializer='lecun_uniform', name = 'prediction')(conc)
    
    model = Model(input=[user_input, item_input,gender_input, age_input], output=prediction)
  
    return model

# %%
k_latents = [20, 30]
drop_out = [0.3, 0.5]
GMF_results_features_add = []
max_age = max(Age)
for do in drop_out:
  for k in k_latents:
    GMF_model = get_gmf_model_gen(max_userid,max_movieid,k,do,max_age)
    GMF_model.compile(loss='mse',optimizer=Adamax(),metrics=['mae'])
    callbacks = [EarlyStopping('val_loss', patience=3)]
    GMF_results_features_add_history = GMF_model.fit([Users, Movies, Gender, Age], Ratings, epochs=1, validation_split=.2, verbose=1, callbacks=callbacks, batch_size = 32)
    GMF_results_features_add.append((k, do, GMF_results_features_add_history))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:21: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("pr...)`
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/1
# 80000/80000 [==============================] - 3s 41us/step - loss: 13.7004 - mean_absolute_error: 3.5284 - val_loss: 13.8335 - val_mean_absolute_error: 3.5359
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/1
# 80000/80000 [==============================] - 4s 47us/step - loss: 3.4531 - mean_absolute_error: 1.4182 - val_loss: 2.2786 - val_mean_absolute_error: 1.2237
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/1
# 80000/80000 [==============================] - 3s 43us/step - loss: 13.7004 - mean_absolute_error: 3.5284 - val_loss: 13.8335 - val_mean_absolute_error: 3.5359
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/1
# ...

# %%
for k, drop_out, history in GMF_results_features_add:
  avg = np.mean(history.history['mean_absolute_error'])
  epochs = len(history.history['mean_absolute_error'])
  minimum = min(history.history['mean_absolute_error'])
  print("drop out of ", drop_out,"and ",  k, " latent dimension in", epochs, "epochs =>",  "Average MAE:", avg, ", Min MAE",minimum)
# Out:
# drop out of  0.3 and  20  latent dimension in 1 epochs => Average MAE: 3.52835 , Min MAE 3.52835
# drop out of  0.3 and  30  latent dimension in 1 epochs => Average MAE: 1.41820553057 , Min MAE 1.41820553057
# drop out of  0.5 and  20  latent dimension in 1 epochs => Average MAE: 3.52835 , Min MAE 3.52835
# drop out of  0.5 and  30  latent dimension in 1 epochs => Average MAE: 3.52835 , Min MAE 3.52835
